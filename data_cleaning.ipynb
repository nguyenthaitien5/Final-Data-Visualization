# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Đọc dữ liệu

# %%
df = pd.read_csv('Raw_DF.csv', encoding='utf-8')
df.head(10)
# Out:
#         price                                        description  \
# 0     5,4 tỷ   + Cần bán gấp đất MINH KHAI.\r\n+ Diện tích 70...
# 1    4,45 tỷ   - Vị trí cự kỳ trắc địa, trung tâm dân cư trí ...
# 2     5,6 tỷ   nhà phố 200m2 - 4 tầng chỉ 5 căn đẹp nhất (mặt...
# 3     1,5 tỷ   - Giá đã gồm bao sang tên, Nhà chính chủ đứng ...
# 4    1,12 tỷ   Chính chủ tên sổ đỏ cần bán\r\nNhà xây 3 tầng ...
# 5   10,28 tỷ   GIẢM CHÀO HƠN 1 TỶ, SÁT QUẬN 1, HẺM NHỰA 8M, 6...
# 6      75 tỷ   Chính chủ cần bán phố Ô Đồng Lầm - mặt Hồ Ba M...
# 7    46,8 tỷ   Cần bán nhà mặt phố Giảng Võ. Diện tích 130m, ...
# 8    1,69 tỷ   Đông Mỹ - sau Sân Bóng oto phi vào nhà,\r\nNhà...
# 9       5 tỷ   CĂN HIẾM CẦU GIẤY – NGÕ QUẬN UỶ - Ô TÔ CÁCH 5M...
#
#                                              address    area  \
# 0   Đường Minh Khai, Phường Minh Khai, Quận Hai B...    70 m
# 1   Đường Lê Trọng Tấn, Phường Sơn Kỳ, Quận Tân P...    64 m
# 2   Đường An Phú Đông 1, Phường An Phú Đông, Quận...    64 m
# 3   Đường Lê Trọng Tấn, Phường Yên Nghĩa, Quận Hà...    31 m
# 4   Đường Biên Giang, Phường Biên Giang, Quận Hà ...    30 m
# 5   Đường Hoàng Hoa Thám, Phường 5, Quận Bình Thạ...    68 m
# 6   Đống Đa, Hà Nội. Đường Hồ Ba Mẫu, Phường Kim ...   300 m
# 7   Phố Giảng Võ, Phường Cát Linh, Quận Đống Đa,...   130 m
# 8   Đường Đông Mỹ, Xã Đông Mỹ, Huyện Thanh Trì, H...    44 m
# 9   Đường Cầu Giấy, Phường Quan Hoa, Quận Cầu Giấ...    45 m
#
#               start_date  end_date floor_number bedroom_number  \
# 0  Ngày đăng: 03/12/2021       NaN            4              3
# 1  Ngày đăng: 03/12/2021       NaN            4              4
# 2  Ngày đăng: 03/12/2021       NaN            4              4
# 3  Ngày đăng: 03/12/2021       NaN            3              3
# 4  Ngày đăng: 03/12/2021       NaN            3              3
# 5  Ngày đăng: 03/12/2021       NaN            4              5
# 6  Ngày đăng: 03/12/2021       NaN            9              8
# 7  Ngày đăng: 03/12/2021       NaN            5              4
# 8  Ngày đăng: 03/12/2021       NaN            3              2
# 9  Ngày đăng: 03/12/2021       NaN            5              5
#
#    is_dinning_room  is_kitchen  is_terrace  is_car_pack  is_owner  \
# 0            False       False       False        False     False
# 1             True        True        True         True     False
# 2             True        True        True         True     False
# 3            False       False       False        False     False
# 4            False       False       False        False     False
# 5            False       False       False        False     False
# 6            False       False       False        False     False
# 7            False       False       False        False     False
# 8            False       False       False        False     False
# 9             True        True        True        False     False
#
#             type direction street_in_front_of_house width height  \
# 0  Nhà trong hẻm         _                       3m  7,7m   9,5m
# 1   Nhà mặt tiền         _                       7m    4m    16m
# 2   Nhà mặt tiền         _                      12m  4,5m    15m
# 3   Nhà mặt tiền  Đông Nam                       3m    4m     8m
# 4  Nhà trong hẻm  Đông Nam                       3m    4m     8m
# 5  Nhà trong hẻm         _                       8m   ---    ---
# 6   Nhà mặt tiền         _                      36m   20m    ---
# 7   Nhà mặt tiền         _                      40m    7m    19m
# 8  Nhà trong hẻm   Tây Bắc                     2,5m    3m  14,6m
# 9   Nhà mặt tiền         _                       3m  4,5m    ---
#
#               law
# 0  Sổ hồng/ Sổ đỏ
# 1             ---
# 2  Sổ hồng/ Sổ đỏ
# 3  Sổ hồng/ Sổ đỏ
# 4  Sổ hồng/ Sổ đỏ
# 5             ---
# 6  Sổ hồng/ Sổ đỏ
# 7  Sổ hồng/ Sổ đỏ
# 8  Sổ hồng/ Sổ đỏ
# 9  Sổ hồng/ Sổ đỏ

# %%
df.shape
# Out:
# (85905, 19)

# %%
print(f"Unique FN: {df['direction'].unique()}")
# Out:
# Unique FN: ['_' 'Đông Nam' 'Tây Bắc' 'Nam' 'Tây Nam' 'Đông Bắc' 'Bắc' 'Tây' 'Đông']

# %% [markdown]
# # Bỏ các hàng chứa giá trị trống

# %%
# df.drop(columns=['description', 'address', 'end_date', 'direction', 'law'], inplace=True)
df.drop(columns=['description', 'end_date', 'direction', 'law'], inplace=True)

# %%
df.head(10)
# Out:
#         price                                            address    area  \
# 0     5,4 tỷ    Đường Minh Khai, Phường Minh Khai, Quận Hai B...    70 m
# 1    4,45 tỷ    Đường Lê Trọng Tấn, Phường Sơn Kỳ, Quận Tân P...    64 m
# 2     5,6 tỷ    Đường An Phú Đông 1, Phường An Phú Đông, Quận...    64 m
# 3     1,5 tỷ    Đường Lê Trọng Tấn, Phường Yên Nghĩa, Quận Hà...    31 m
# 4    1,12 tỷ    Đường Biên Giang, Phường Biên Giang, Quận Hà ...    30 m
# 5   10,28 tỷ    Đường Hoàng Hoa Thám, Phường 5, Quận Bình Thạ...    68 m
# 6      75 tỷ    Đống Đa, Hà Nội. Đường Hồ Ba Mẫu, Phường Kim ...   300 m
# 7    46,8 tỷ    Phố Giảng Võ, Phường Cát Linh, Quận Đống Đa,...   130 m
# 8    1,69 tỷ    Đường Đông Mỹ, Xã Đông Mỹ, Huyện Thanh Trì, H...    44 m
# 9       5 tỷ    Đường Cầu Giấy, Phường Quan Hoa, Quận Cầu Giấ...    45 m
#
#               start_date floor_number bedroom_number  is_dinning_room  \
# 0  Ngày đăng: 03/12/2021            4              3            False
# 1  Ngày đăng: 03/12/2021            4              4             True
# 2  Ngày đăng: 03/12/2021            4              4             True
# 3  Ngày đăng: 03/12/2021            3              3            False
# 4  Ngày đăng: 03/12/2021            3              3            False
# 5  Ngày đăng: 03/12/2021            4              5            False
# 6  Ngày đăng: 03/12/2021            9              8            False
# 7  Ngày đăng: 03/12/2021            5              4            False
# 8  Ngày đăng: 03/12/2021            3              2            False
# 9  Ngày đăng: 03/12/2021            5              5             True
#
#    is_kitchen  is_terrace  is_car_pack  is_owner           type  \
# 0       False       False        False     False  Nhà trong hẻm
# 1        True        True         True     False   Nhà mặt tiền
# 2        True        True         True     False   Nhà mặt tiền
# 3       False       False        False     False   Nhà mặt tiền
# 4       False       False        False     False  Nhà trong hẻm
# 5       False       False        False     False  Nhà trong hẻm
# 6       False       False        False     False   Nhà mặt tiền
# 7       False       False        False     False   Nhà mặt tiền
# 8       False       False        False     False  Nhà trong hẻm
# 9        True        True        False     False   Nhà mặt tiền
#
#   street_in_front_of_house width height
# 0                       3m  7,7m   9,5m
# 1                       7m    4m    16m
# 2                      12m  4,5m    15m
# 3                       3m    4m     8m
# 4                       3m    4m     8m
# 5                       8m   ---    ---
# 6                      36m   20m    ---
# 7                      40m    7m    19m
# 8                     2,5m    3m  14,6m
# 9                       3m  4,5m    ---

# %%
# df.replace('_', np.NaN, inplace=True)
df.replace('---', np.NaN, inplace=True)
df.head(10)
# Out:
#         price                                            address    area  \
# 0     5,4 tỷ    Đường Minh Khai, Phường Minh Khai, Quận Hai B...    70 m
# 1    4,45 tỷ    Đường Lê Trọng Tấn, Phường Sơn Kỳ, Quận Tân P...    64 m
# 2     5,6 tỷ    Đường An Phú Đông 1, Phường An Phú Đông, Quận...    64 m
# 3     1,5 tỷ    Đường Lê Trọng Tấn, Phường Yên Nghĩa, Quận Hà...    31 m
# 4    1,12 tỷ    Đường Biên Giang, Phường Biên Giang, Quận Hà ...    30 m
# 5   10,28 tỷ    Đường Hoàng Hoa Thám, Phường 5, Quận Bình Thạ...    68 m
# 6      75 tỷ    Đống Đa, Hà Nội. Đường Hồ Ba Mẫu, Phường Kim ...   300 m
# 7    46,8 tỷ    Phố Giảng Võ, Phường Cát Linh, Quận Đống Đa,...   130 m
# 8    1,69 tỷ    Đường Đông Mỹ, Xã Đông Mỹ, Huyện Thanh Trì, H...    44 m
# 9       5 tỷ    Đường Cầu Giấy, Phường Quan Hoa, Quận Cầu Giấ...    45 m
#
#               start_date floor_number bedroom_number  is_dinning_room  \
# 0  Ngày đăng: 03/12/2021            4              3            False
# 1  Ngày đăng: 03/12/2021            4              4             True
# 2  Ngày đăng: 03/12/2021            4              4             True
# 3  Ngày đăng: 03/12/2021            3              3            False
# 4  Ngày đăng: 03/12/2021            3              3            False
# 5  Ngày đăng: 03/12/2021            4              5            False
# 6  Ngày đăng: 03/12/2021            9              8            False
# 7  Ngày đăng: 03/12/2021            5              4            False
# 8  Ngày đăng: 03/12/2021            3              2            False
# 9  Ngày đăng: 03/12/2021            5              5             True
#
#    is_kitchen  is_terrace  is_car_pack  is_owner           type  \
# 0       False       False        False     False  Nhà trong hẻm
# 1        True        True         True     False   Nhà mặt tiền
# 2        True        True         True     False   Nhà mặt tiền
# 3       False       False        False     False   Nhà mặt tiền
# 4       False       False        False     False  Nhà trong hẻm
# 5       False       False        False     False  Nhà trong hẻm
# 6       False       False        False     False   Nhà mặt tiền
# 7       False       False        False     False   Nhà mặt tiền
# 8       False       False        False     False  Nhà trong hẻm
# 9        True        True        False     False   Nhà mặt tiền
#
#   street_in_front_of_house width height
# 0                       3m  7,7m   9,5m
# 1                       7m    4m    16m
# 2                      12m  4,5m    15m
# 3                       3m    4m     8m
# 4                       3m    4m     8m
# 5                       8m   NaN    NaN
# 6                      36m   20m    NaN
# 7                      40m    7m    19m
# 8                     2,5m    3m  14,6m
# 9                       3m  4,5m    NaN

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (42495, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42495 entries, 0 to 85904
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   price                     42495 non-null  object
#  1   address                   42495 non-null  object
#  2   area                      42495 non-null  object
#  3   start_date                42495 non-null  object
#  4   floor_number              42495 non-null  object
#  5   bedroom_number            42495 non-null  object
#  6   is_dinning_room           42495 non-null  bool
#  7   is_kitchen                42495 non-null  bool
#  8   is_terrace                42495 non-null  bool
#  9   is_car_pack               42495 non-null  bool
#  10  is_owner                  42495 non-null  bool
#  11  type                      42495 non-null  object
#  12  street_in_front_of_house  42495 non-null  object
#  13  width                     42495 non-null  object
#  14  height                    42495 non-null  object
# dtypes: bool(5), object(10)
# memory usage: 3.8+ MB

# %% [markdown]
# # Xử lý các cột chứa chuỗi để lấy thông tin

# %%
import re

# %%
def strip_str(s):
#     postfix = s.strip(' ')[-1]
#     if postfix != 'm':
#         s = np.NaN
#         return s
    if s.count('m') != 1:
        return np.NaN
    x = re.search("[+-]?([0-9]*[,])?[0-9]+", s)
    if(x != None):
        s = float(s[x.start(): x.end()].replace(',', '.'))
    else:
        s = np.NaN
    return s
    
df['width'] = df['width'].apply(strip_str)
df['height'] = df['height'].apply(strip_str)
df['area'] = df['area'].apply(strip_str)
df['street_in_front_of_house'] = df['street_in_front_of_house'].apply(strip_str)
df.head(10)
# Out:
#         price                                            address   area  \
# 0     5,4 tỷ    Đường Minh Khai, Phường Minh Khai, Quận Hai B...   70.0
# 1    4,45 tỷ    Đường Lê Trọng Tấn, Phường Sơn Kỳ, Quận Tân P...   64.0
# 2     5,6 tỷ    Đường An Phú Đông 1, Phường An Phú Đông, Quận...   64.0
# 3     1,5 tỷ    Đường Lê Trọng Tấn, Phường Yên Nghĩa, Quận Hà...   31.0
# 4    1,12 tỷ    Đường Biên Giang, Phường Biên Giang, Quận Hà ...   30.0
# 7    46,8 tỷ    Phố Giảng Võ, Phường Cát Linh, Quận Đống Đa,...  130.0
# 8    1,69 tỷ    Đường Đông Mỹ, Xã Đông Mỹ, Huyện Thanh Trì, H...   44.0
# 12   15,2 tỷ    Đường Nguyễn Sơn, Phường Phú Thạnh, Quận Tân ...   80.0
# 13    4,8 tỷ    Đường Hà Huy Giáp, Phường Thạnh Xuân, Quận 12...   60.0
# 14   3,95 tỷ     Đường số 1, Phường Tân Phú, Quận 7, Hồ Chí Minh   95.0
#
#                start_date floor_number bedroom_number  is_dinning_room  \
# 0   Ngày đăng: 03/12/2021            4              3            False
# 1   Ngày đăng: 03/12/2021            4              4             True
# 2   Ngày đăng: 03/12/2021            4              4             True
# 3   Ngày đăng: 03/12/2021            3              3            False
# 4   Ngày đăng: 03/12/2021            3              3            False
# 7   Ngày đăng: 03/12/2021            5              4            False
# 8   Ngày đăng: 03/12/2021            3              2            False
# 12  Ngày đăng: 03/12/2021            5              6             True
# 13  Ngày đăng: 03/12/2021            4              4             True
# 14  Ngày đăng: 03/12/2021            2              4             True
#
#     is_kitchen  is_terrace  is_car_pack  is_owner           type  \
# 0        False       False        False     False  Nhà trong hẻm
# 1         True        True         True     False   Nhà mặt tiền
# 2         True        True         True     False   Nhà mặt tiền
# 3        False       False        False     False   Nhà mặt tiền
# 4        False       False        False     False  Nhà trong hẻm
# 7        False       False        False     False   Nhà mặt tiền
# 8        False       False        False     False  Nhà trong hẻm
# 12        True        True         True     False   Nhà mặt tiền
# 13        True        True         True     False   Nhà mặt tiền
# 14        True        True         True     False   Nhà mặt tiền
#
#     street_in_front_of_house  width  height
# 0                        3.0    7.7     9.5
# 1                        7.0    4.0    16.0
# 2                       12.0    4.5    15.0
# 3                        3.0    4.0     8.0
# 4                        3.0    4.0     8.0
# 7                       40.0    7.0    19.0
# 8                        2.5    3.0    14.6
# 12                      12.0    4.0    20.0
# 13                      12.0    4.0    15.0
# 14                       8.0    5.0    19.0

# %%
print(strip_str('3,6 tỷ'))
# Out:
# nan

# %%
def find_str(s):
    x = re.search("[+-]?([0-9]*[,])?[0-9]+", s)
    if(x != None):
        # x.end() là index của giá trị khoảng trắng sau số cuối cùng, nên cần cộng 1 để tính từ ký tự tiếp theo
        s = s[x.end() + 1 : len(s)]
    return s
def strip_str_price(s):
    x = re.search("[+-]?([0-9]*[,])?[0-9]+", s)
    if(x != None):
        s = float(s[x.start(): x.end()].replace(',', '.'))
    else:
        s = np.NaN
    return s
df['postfix_price'] = df['price'].apply(find_str)
df['price'] = df['price'].apply(strip_str_price)
df.head(100)
# Out:
#       price                                            address   area  \
# 0      5.40   Đường Minh Khai, Phường Minh Khai, Quận Hai B...   70.0
# 1      4.45   Đường Lê Trọng Tấn, Phường Sơn Kỳ, Quận Tân P...   64.0
# 2      5.60   Đường An Phú Đông 1, Phường An Phú Đông, Quận...   64.0
# 3      1.50   Đường Lê Trọng Tấn, Phường Yên Nghĩa, Quận Hà...   31.0
# 4      1.12   Đường Biên Giang, Phường Biên Giang, Quận Hà ...   30.0
# ..      ...                                                ...    ...
# 126    3.65   Đường Dương Tử Giang, Phường 14, Quận 5, Hồ C...   90.0
# 127  800.00   Đinh Đức Thiện Đường Đinh Đức Thiện, Xã Bình ...  100.0
# 128   16.30   Đường Nguyễn Thông, Phường 7, Quận 3, Hồ Chí ...   80.0
# 129    3.40   40 Đường Mỹ Đình, Phường Mỹ Đình 1, Quận Nam ...   35.0
# 130   40.00    Đường Xóm Chiếu, Phường 14, Quận 4, Hồ Chí Minh  350.0
#
#                 start_date floor_number bedroom_number  is_dinning_room  \
# 0    Ngày đăng: 03/12/2021            4              3            False
# 1    Ngày đăng: 03/12/2021            4              4             True
# 2    Ngày đăng: 03/12/2021            4              4             True
# 3    Ngày đăng: 03/12/2021            3              3            False
# 4    Ngày đăng: 03/12/2021            3              3            False
# ..                     ...          ...            ...              ...
# 126  Ngày đăng: 03/12/2021            3              4            False
# 127  Ngày đăng: 02/12/2021            2              3             True
# 128  Ngày đăng: 03/12/2021            6             12            False
# 129  Ngày đăng: 02/12/2021            5              4             True
# 130  Ngày đăng: 02/12/2021            1             10            False
#
#      is_kitchen  is_terrace  is_car_pack  is_owner           type  \
# 0         False       False        False     False  Nhà trong hẻm
# 1          True        True         True     False   Nhà mặt tiền
# 2          True        True         True     False   Nhà mặt tiền
# 3         False       False        False     False   Nhà mặt tiền
# 4         False       False        False     False  Nhà trong hẻm
# ..          ...         ...          ...       ...            ...
# 126       False       False        False     False   Nhà mặt tiền
# 127        True        True         True     False   Nhà mặt tiền
# 128       False       False        False     False   Nhà mặt tiền
# 129       False        True        False     False  Nhà trong hẻm
# 130       False       False        False     False   Nhà mặt tiền
#
#      street_in_front_of_house  width  height postfix_price
# 0                         3.0    7.7     9.5           tỷ
# 1                         7.0    4.0    16.0           tỷ
# 2                        12.0    4.5    15.0           tỷ
# 3                         3.0    4.0     8.0           tỷ
# 4                         3.0    4.0     8.0           tỷ
# ..                        ...    ...     ...           ...
# 126                       6.0    5.0    16.0           tỷ
# 127                      15.0    5.0    20.0        triệu
# 128                      15.0    4.0    20.0           tỷ
# 129                       3.0    3.5    10.0           tỷ
# 130                      12.0    8.0    35.0           tỷ
#
# [100 rows x 16 columns]

# %%
print(f"Unique FN: {df['postfix_price'].unique()}")
# Out:
# Unique FN: ['tỷ ' 'triệu /\xa0m' 'triệu ' 'ngàn ' ' Thỏa thuận' 'tỷ /\xa0m'
#  'ngàn /\xa0m' 'tỷ 4 ngàn ']

# %%
def replace_price(row):
    if row['postfix_price'] == "tỷ ":
        return row['price']
    elif  row['postfix_price'] == "triệu ":
        return row['price'] /1000
    else :
        return np.NaN
    
df['price'] = df.apply (lambda row: replace_price(row), axis=1)
# df['price'] = df['price'].apply(replace_price)

# %%
df.head(10)
# Out:
#     price                                            address   area  \
# 0    5.40   Đường Minh Khai, Phường Minh Khai, Quận Hai B...   70.0
# 1    4.45   Đường Lê Trọng Tấn, Phường Sơn Kỳ, Quận Tân P...   64.0
# 2    5.60   Đường An Phú Đông 1, Phường An Phú Đông, Quận...   64.0
# 3    1.50   Đường Lê Trọng Tấn, Phường Yên Nghĩa, Quận Hà...   31.0
# 4    1.12   Đường Biên Giang, Phường Biên Giang, Quận Hà ...   30.0
# 7   46.80   Phố Giảng Võ, Phường Cát Linh, Quận Đống Đa,...  130.0
# 8    1.69   Đường Đông Mỹ, Xã Đông Mỹ, Huyện Thanh Trì, H...   44.0
# 12  15.20   Đường Nguyễn Sơn, Phường Phú Thạnh, Quận Tân ...   80.0
# 13   4.80   Đường Hà Huy Giáp, Phường Thạnh Xuân, Quận 12...   60.0
# 14   3.95    Đường số 1, Phường Tân Phú, Quận 7, Hồ Chí Minh   95.0
#
#                start_date floor_number bedroom_number  is_dinning_room  \
# 0   Ngày đăng: 03/12/2021            4              3            False
# 1   Ngày đăng: 03/12/2021            4              4             True
# 2   Ngày đăng: 03/12/2021            4              4             True
# 3   Ngày đăng: 03/12/2021            3              3            False
# 4   Ngày đăng: 03/12/2021            3              3            False
# 7   Ngày đăng: 03/12/2021            5              4            False
# 8   Ngày đăng: 03/12/2021            3              2            False
# 12  Ngày đăng: 03/12/2021            5              6             True
# 13  Ngày đăng: 03/12/2021            4              4             True
# 14  Ngày đăng: 03/12/2021            2              4             True
#
#     is_kitchen  is_terrace  is_car_pack  is_owner           type  \
# 0        False       False        False     False  Nhà trong hẻm
# 1         True        True         True     False   Nhà mặt tiền
# 2         True        True         True     False   Nhà mặt tiền
# 3        False       False        False     False   Nhà mặt tiền
# 4        False       False        False     False  Nhà trong hẻm
# 7        False       False        False     False   Nhà mặt tiền
# 8        False       False        False     False  Nhà trong hẻm
# 12        True        True         True     False   Nhà mặt tiền
# 13        True        True         True     False   Nhà mặt tiền
# 14        True        True         True     False   Nhà mặt tiền
#
#     street_in_front_of_house  width  height postfix_price
# 0                        3.0    7.7     9.5           tỷ
# 1                        7.0    4.0    16.0           tỷ
# 2                       12.0    4.5    15.0           tỷ
# 3                        3.0    4.0     8.0           tỷ
# 4                        3.0    4.0     8.0           tỷ
# 7                       40.0    7.0    19.0           tỷ
# 8                        2.5    3.0    14.6           tỷ
# 12                      12.0    4.0    20.0           tỷ
# 13                      12.0    4.0    15.0           tỷ
# 14                       8.0    5.0    19.0           tỷ

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (42124, 16)

# %%
def split_address(row):
    x = re.split(',', row['address'])
    district = x[-2].strip()
    province = x[-1].strip()
    row['district'] = district
    row['province'] = province
    return row


df = df.apply(lambda row: split_address(row), axis=1)

# %%
df.head(10)
# Out:
#     price                                            address   area  \
# 0    5.40   Đường Minh Khai, Phường Minh Khai, Quận Hai B...   70.0
# 1    4.45   Đường Lê Trọng Tấn, Phường Sơn Kỳ, Quận Tân P...   64.0
# 2    5.60   Đường An Phú Đông 1, Phường An Phú Đông, Quận...   64.0
# 3    1.50   Đường Lê Trọng Tấn, Phường Yên Nghĩa, Quận Hà...   31.0
# 4    1.12   Đường Biên Giang, Phường Biên Giang, Quận Hà ...   30.0
# 7   46.80   Phố Giảng Võ, Phường Cát Linh, Quận Đống Đa,...  130.0
# 8    1.69   Đường Đông Mỹ, Xã Đông Mỹ, Huyện Thanh Trì, H...   44.0
# 12  15.20   Đường Nguyễn Sơn, Phường Phú Thạnh, Quận Tân ...   80.0
# 13   4.80   Đường Hà Huy Giáp, Phường Thạnh Xuân, Quận 12...   60.0
# 14   3.95    Đường số 1, Phường Tân Phú, Quận 7, Hồ Chí Minh   95.0
#
#                start_date floor_number bedroom_number  is_dinning_room  \
# 0   Ngày đăng: 03/12/2021            4              3            False
# 1   Ngày đăng: 03/12/2021            4              4             True
# 2   Ngày đăng: 03/12/2021            4              4             True
# 3   Ngày đăng: 03/12/2021            3              3            False
# 4   Ngày đăng: 03/12/2021            3              3            False
# 7   Ngày đăng: 03/12/2021            5              4            False
# 8   Ngày đăng: 03/12/2021            3              2            False
# 12  Ngày đăng: 03/12/2021            5              6             True
# 13  Ngày đăng: 03/12/2021            4              4             True
# 14  Ngày đăng: 03/12/2021            2              4             True
#
#     is_kitchen  is_terrace  is_car_pack  is_owner           type  \
# 0        False       False        False     False  Nhà trong hẻm
# 1         True        True         True     False   Nhà mặt tiền
# 2         True        True         True     False   Nhà mặt tiền
# 3        False       False        False     False   Nhà mặt tiền
# 4        False       False        False     False  Nhà trong hẻm
# 7        False       False        False     False   Nhà mặt tiền
# 8        False       False        False     False  Nhà trong hẻm
# 12        True        True         True     False   Nhà mặt tiền
# 13        True        True         True     False   Nhà mặt tiền
# 14        True        True         True     False   Nhà mặt tiền
#
#     street_in_front_of_house  width  height postfix_price           district  \
# 0                        3.0    7.7     9.5           tỷ   Quận Hai Bà Trưng
# 1                        7.0    4.0    16.0           tỷ        Quận Tân Phú
# 2                       12.0    4.5    15.0           tỷ             Quận 12
# 3                        3.0    4.0     8.0           tỷ        Quận Hà Đông
# 4                        3.0    4.0     8.0           tỷ        Quận Hà Đông
# 7                       40.0    7.0    19.0           tỷ        Quận Đống Đa
# 8                        2.5    3.0    14.6           tỷ     Huyện Thanh Trì
# 12                      12.0    4.0    20.0           tỷ        Quận Tân Phú
# 13                      12.0    4.0    15.0           tỷ             Quận 12
# 14                       8.0    5.0    19.0           tỷ              Quận 7
#
#        province
# 0        Hà Nội
# 1   Hồ Chí Minh
# 2   Hồ Chí Minh
# 3        Hà Nội
# 4        Hà Nội
# 7        Hà Nội
# 8        Hà Nội
# 12  Hồ Chí Minh
# 13  Hồ Chí Minh
# 14  Hồ Chí Minh

# %%
def replace_date(s):
    x = re.search("(0[1-9]|[12][0-9]|3[01])[- /.](0[1-9]|1[012])[- /.](19|20)\d\d",s)
    if (x != None):
        s = s[x.start() : x.end()]
    return s
    
df['start_date'] = pd.to_datetime(df['start_date'].apply(replace_date) ,format= "%d/%m/%Y")

# %%
# test = 'Ngày đăng: 31/12/2021'
# x = re.search("(0[1-9]|[12][0-9]|3[01])[- /.](0[1-9]|1[012])[- /.](19|20)\d\d",test)
# print(test[x.start() : x.end()])

# %%
# print(df['start_date'][0].day)
df.drop(columns=['address', 'postfix_price'], inplace=True)
df.head(10)
# Out:
#     price   area start_date floor_number bedroom_number  is_dinning_room  \
# 0    5.40   70.0 2021-12-03            4              3            False
# 1    4.45   64.0 2021-12-03            4              4             True
# 2    5.60   64.0 2021-12-03            4              4             True
# 3    1.50   31.0 2021-12-03            3              3            False
# 4    1.12   30.0 2021-12-03            3              3            False
# 7   46.80  130.0 2021-12-03            5              4            False
# 8    1.69   44.0 2021-12-03            3              2            False
# 12  15.20   80.0 2021-12-03            5              6             True
# 13   4.80   60.0 2021-12-03            4              4             True
# 14   3.95   95.0 2021-12-03            2              4             True
#
#     is_kitchen  is_terrace  is_car_pack  is_owner           type  \
# 0        False       False        False     False  Nhà trong hẻm
# 1         True        True         True     False   Nhà mặt tiền
# 2         True        True         True     False   Nhà mặt tiền
# 3        False       False        False     False   Nhà mặt tiền
# 4        False       False        False     False  Nhà trong hẻm
# 7        False       False        False     False   Nhà mặt tiền
# 8        False       False        False     False  Nhà trong hẻm
# 12        True        True         True     False   Nhà mặt tiền
# 13        True        True         True     False   Nhà mặt tiền
# 14        True        True         True     False   Nhà mặt tiền
#
#     street_in_front_of_house  width  height           district     province
# 0                        3.0    7.7     9.5  Quận Hai Bà Trưng       Hà Nội
# 1                        7.0    4.0    16.0       Quận Tân Phú  Hồ Chí Minh
# 2                       12.0    4.5    15.0            Quận 12  Hồ Chí Minh
# 3                        3.0    4.0     8.0       Quận Hà Đông       Hà Nội
# 4                        3.0    4.0     8.0       Quận Hà Đông       Hà Nội
# 7                       40.0    7.0    19.0       Quận Đống Đa       Hà Nội
# 8                        2.5    3.0    14.6    Huyện Thanh Trì       Hà Nội
# 12                      12.0    4.0    20.0       Quận Tân Phú  Hồ Chí Minh
# 13                      12.0    4.0    15.0            Quận 12  Hồ Chí Minh
# 14                       8.0    5.0    19.0             Quận 7  Hồ Chí Minh

# %% [markdown]
# # Phân tích dữ liệu

# %%
df['price'].describe()
# Out:
# count    42124.000000
# mean        18.384752
# std         41.545258
# min          0.012900
# 25%          4.350000
# 50%          7.450000
# 75%         16.400000
# max       1100.000000
# Name: price, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style = 'darkgrid')

# %%
features_numerical = df.select_dtypes(exclude=['object', 'bool', 'datetime']).copy()
features_numerical.columns
# Out:
# Index(['price', 'area', 'street_in_front_of_house', 'width', 'height'], dtype='object')

# %% [markdown]
# # Nhận xét cột numeric
#
# Có nhiều outlier, do đó cần trực quan và loại bỏ đi các outlier này, chỉ giữ lại những giá trị khả thi, hoặc không quá lệch so với trung bình và trung vị

# %%
# fig, f_axes = plt.subplots(ncols=2, nrows=2, constrained_layout=True)
sns.set(style = 'whitegrid')
for i in range(len(features_numerical.columns)):
#     fig.add_subplot(10, 8, i+1)
    fig = plt.figure(figsize = (10,10))
    sns.histplot(features_numerical.iloc[:,i])
    plt.xlabel(features_numerical.columns[i])
    plt.show()
    plt.close()

# %%
df.drop(df[df.price > 45].index, inplace = True)
df.drop(df[df.area > 200].index, inplace = True)
df.drop(df[df.street_in_front_of_house > 50].index, inplace = True)
df.drop(df[df.width > 60].index, inplace = True)
df.drop(df[df.height > 60].index, inplace = True)

# %% [markdown]
# Sau khi loại bỏ các outlier

# %%
features_numerical = df.select_dtypes(exclude=['object', 'bool', 'datetime']).copy()

# fig, f_axes = plt.subplots(ncols=2, nrows=2, constrained_layout=True)
sns.set(style = 'whitegrid')
for i in range(len(features_numerical.columns)):
#     fig.add_subplot(10, 8, i+1)
    fig = plt.figure(figsize = (10,10))
    sns.boxplot(features_numerical.iloc[:,i])
    plt.xlabel(features_numerical.columns[i])
    plt.show()
    plt.close()
# Out:
# C:\Users\kvmduc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kvmduc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kvmduc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kvmduc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kvmduc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.to_csv('Processed_Data.csv', index=False)
